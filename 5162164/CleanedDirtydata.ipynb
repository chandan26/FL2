# %%
# Importing libraries
import pandas as pd
import numpy as np

# Read csv file into a pandas dataframe
df = pd.read_csv("31084524_dirty_data.csv")

# Take a look at the first few rows
df.head()
# Out:
#     order_id   customer_id        date nearest_warehouse  \
# 0  ORD196541  ID1283628999  2019-09-17          Thompson
# 1  ORD288326  ID1479905345  2019-05-25         Nickolson
# 2  ORD118948  ID0575386501  2019-07-28         Nickolson
# 3  ORD351033  ID0030287874  2019-07-12            Bakers
# 4  ORD198886  ID5563404259  2019-04-13            Bakers
#
#                                        shopping_cart  order_price  \
# 0  [('iAssist Line', 2), ('iStream', 2), ('Univer...        11650
# 1  [('Toshika 750', 2), ('iStream', 1), ('Lucent ...        11250
# 2  [('Thunder line', 2), ('Alcon 10', 2), ('Toshi...        26880
# 3  [('Toshika 750', 1), ('Universe Note', 1), ('A...        25670
# 4  [('iStream', 2), ('Toshika 750', 1), ('Lucent ...        13390
#
#    delivery_charges  customer_lat  customer_long  coupon_discount  \
# 0            108.90    -37.799723     144.955257                5
# 1             80.15    -37.820750     144.957444                5
# ...

# %%
df['shopping_cart'] =  df['shopping_cart'].apply(lambda x: x.replace('[(','').replace(']',''))

# %%
df
# Out:
#       order_id   customer_id        date nearest_warehouse  \
# 0    ORD196541  ID1283628999  2019-09-17          Thompson
# 1    ORD288326  ID1479905345  2019-05-25         Nickolson
# 2    ORD118948  ID0575386501  2019-07-28         Nickolson
# 3    ORD351033  ID0030287874  2019-07-12            Bakers
# 4    ORD198886  ID5563404259  2019-04-13            Bakers
# ..         ...           ...         ...               ...
# 495  ORD496551  ID0579994804  2019-02-14          Thompson
# 496  ORD465466  ID6197211189  2019-10-13          Thompson
# 497  ORD206695  ID0778942366  2019-13-01            Bakers
# 498  ORD375794  ID0306067099  2019-10-15         Nickolson
# 499  ORD265535  ID0126934555  2019-06-23         Nickolson
#
#                                          shopping_cart  order_price  \
# 0    'iAssist Line', 2), ('iStream', 2), ('Universe...        11650
# 1    'Toshika 750', 2), ('iStream', 1), ('Lucent 33...        11250
# ...

# %%
df['shopping_cart'] =  df['shopping_cart'].apply(lambda x: x.replace('(','').replace(')',''))

# %%
df
# Out:
#       order_id   customer_id        date nearest_warehouse  \
# 0    ORD196541  ID1283628999  2019-09-17          Thompson
# 1    ORD288326  ID1479905345  2019-05-25         Nickolson
# 2    ORD118948  ID0575386501  2019-07-28         Nickolson
# 3    ORD351033  ID0030287874  2019-07-12            Bakers
# 4    ORD198886  ID5563404259  2019-04-13            Bakers
# ..         ...           ...         ...               ...
# 495  ORD496551  ID0579994804  2019-02-14          Thompson
# 496  ORD465466  ID6197211189  2019-10-13          Thompson
# 497  ORD206695  ID0778942366  2019-13-01            Bakers
# 498  ORD375794  ID0306067099  2019-10-15         Nickolson
# 499  ORD265535  ID0126934555  2019-06-23         Nickolson
#
#                                          shopping_cart  order_price  \
# 0    'iAssist Line', 2, 'iStream', 2, 'Universe Not...        11650
# 1     'Toshika 750', 2, 'iStream', 1, 'Lucent 330S', 2        11250
# ...

# %%
df['shopping_cart'].head(2)
# Out:
# 0    'iAssist Line', 2, 'iStream', 2, 'Universe Not...
# 1     'Toshika 750', 2, 'iStream', 1, 'Lucent 330S', 2
# Name: shopping_cart, dtype: object
