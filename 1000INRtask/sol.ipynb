# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("us-states.csv")

# %%
df
# Out:
#              date          state  fips   cases  deaths
# 0      2020-01-21     Washington    53       1       0
# 1      2020-01-22     Washington    53       1       0
# 2      2020-01-23     Washington    53       1       0
# 3      2020-01-24       Illinois    17       1       0
# 4      2020-01-24     Washington    53       1       0
# ...           ...            ...   ...     ...     ...
# 12274  2020-10-11       Virginia    51  158716    3358
# 12275  2020-10-11     Washington    53   97527    2289
# 12276  2020-10-11  West Virginia    54   18128     382
# 12277  2020-10-11      Wisconsin    55  158426    1477
# 12278  2020-10-11        Wyoming    56    7611      54
#
# [12279 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# date      0
# state     0
# fips      0
# cases     0
# deaths    0
# dtype: int64

# %%
df.describe().to_csv('describe.csv')

# %%
plt.figure(figsize=(12,8))
#plt.xlabel("X axis label")
plt.ylabel("Deaths")
df.groupby(['state'])['deaths'].sum().sort_values(ascending=False).plot(kind='bar')

# %%
plt.figure(figsize=(12,8))
#plt.xlabel("X axis label")
plt.ylabel("Cases")
df.groupby(['state'])['cases'].sum().sort_values(ascending=False).plot(kind='bar')

# %%
plt.figure(figsize=(12,8))
#plt.xlabel("X axis label")
plt.ylabel("Deaths")
df.groupby(['fips'])['deaths'].sum().sort_values(ascending=False).plot(kind='bar')

# %%
df.dtypes
# Out:
# date      object
# state     object
# fips       int64
# cases      int64
# deaths     int64
# dtype: object

# %%
df.hist(column='deaths')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001CA8FED0370>]],
#       dtype=object)

# %%
df.hist(column='cases')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001CA9571BD30>]],
#       dtype=object)
